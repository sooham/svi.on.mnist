# %%
from sudoku import Sudoku, SudokuGenerator

# %%
generator = SudokuGenerator(backend='torch', bit_width='4bit')
puzzle = generator.generate_puzzle('medium')

# %%
test_sequence = generator.generate_diffusion_sequence(1000)
generator.visualize_diffusion_sequence(test_sequence, timesteps=1)
