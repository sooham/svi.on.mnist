# %%
from sudoku import Sudoku, SudokuGenerator

# %%
generator = SudokuGenerator(backend='numpy', bit_width='4bit')
puzzle = generator.generate_puzzle('medium')

# %%
test_sequence = generator.generate_diffusion_sequence(5)
generator.visualize_diffusion_sequence(test_sequence)
